# %%
# %sql
-- RUN PERIODICCALY TO OPTIMIZE PERFOMANCE AND QUERY COST

OPTIMIZE my_spotify.silver.user_recent_played
 ZORDER BY played_at

# %%
# %skip
# %sql
DESCRIBE HISTORY my_spotify.silver.user_recent_played;
