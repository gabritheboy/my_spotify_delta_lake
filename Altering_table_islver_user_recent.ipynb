# %%
columns = spark.sql("SELECT * FROM my_spotify.silver.user_recent_played Limit 1").columns
print(columns)

# %%
# %sql
ALTER TABLE my_spotify.silver.user_recent_played
ADD COLUMN (ingested_ts TIMESTAMP)

# %%
# %sql
ALTER TABLE my_spotify.silver.user_recent_played
SET TBLPROPERTIES ('delta.columnMapping.mode' = 'name');

# %%
# %sql
ALTER TABLE my_spotify.silver.user_recent_played
DROP COLUMNS (first_artist_name,
album_name,
duration_ms,
second_artist_id,
second_artist_name,
popularity,
album_release_date
)

# %%
# %sql
ALTER TABLE my_spotify.silver.user_recent_played
ADD COLUMN (time_of_day STRING)

# %%
# %sql
UPDATE  my_spotify.silver.user_recent_played
SET played_at = played_at + INTERVAL 1 HOUR;
